# %% [markdown]
# # Finansal Simülasyon - Düzeltme Laboratuvarı
#
# Bu notebook, BIST, Döviz, Mevduat, Altın ve Gayrimenkul fonksiyonlarını test etmek ve tek potada enflasyon/faiz dinamiklerine bağlamak için kullanılacaktır.

# %%
import random

def normal(ortalama, std, min_val=None, max_val=None):
    deger = random.gauss(ortalama, std)
    if min_val is not None:
        deger = max(deger, min_val)
    if max_val is not None:
        deger = min(deger, max_val)
    return round(deger, 4)

# %% [markdown]
# ### 1. Döviz Düzeltmesi (Kur artışını PPP/Enflasyon farkına yaklaştırmak)

# %%
def doviz_sim_yeni(enflasyon, rejim):
    # Çarpanlar eskiden 2.0 ve 1.5'ti. Şimdi enflasyonla başa baş gidecek şekilde (1.0 - 1.1) ayarlanabilir.
    pass

# %% [markdown]
# ### 2. Borsa ve Sektör Düzeltmesi (Nominal getiri + Faiz Duyarlılığı)

# %%
def bist_getiri_uret_yeni(faiz_yon, enflasyon, faiz, enf_rejim=0):
    # Enflasyon doğrudan taban getiri olmalı. BIST Getirisi = Enflasyon + Reel Getiri
    # Reel getiri faiz_yon'e (faiz kararına) çok duyarlı olmalı.
    pass
